# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
from scipy.optimize import basinhopping
import math
# %matplotlib inline

# %%
yn=1
h=0.01
t=0.01
time=[]
y=[]
time.append(t)
y.append(yn)
for i in range(1000):
    t+=(h)
    yn+=(-yn*h)
    y.append(yn);
    time.append(t)
print(y)
print(time)
# Out:
# [1, 0.99, 0.9801, 0.970299, 0.9605960100000001, 0.9509900499, 0.941480149401, 0.93206534790699, 0.9227446944279202, 0.9135172474836409, 0.9043820750088045, 0.8953382542587165, 0.8863848717161293, 0.8775210229989681, 0.8687458127689783, 0.8600583546412885, 0.8514577710948756, 0.8429431933839269, 0.8345137614500876, 0.8261686238355868, 0.8179069375972309, 0.8097278682212585, 0.801630589539046, 0.7936142836436555, 0.785678140807219, 0.7778213593991468, 0.7700431458051553, 0.7623427143471038, 0.7547192872036327, 0.7471720943315964, 0.7397003733882804, 0.7323033696543976, 0.7249803359578536, 0.717730532598275, 0.7105532272722923, 0.7034476949995694, 0.6964132180495737, 0.6894490858690779, 0.6825545950103872, 0.6757290490602833, 0.6689717585696805, 0.6622820409839837, 0.6556592205741438, 0.6491026283684024, 0.6426116020847183, 0.6361854860638712, 0.6298236312032325, 0.6235253948912002, 0.6172901409422882, 0.6111172395328653, 0.6050060671375367, 0.5989560064661613, 0.5929664464014998, 0.587
# ...

# %%
plt.plot(time,y)
