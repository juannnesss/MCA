# %%
import math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
datos=np.loadtxt('datos170.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
x=X[0:400]
print x[-1]
print max(Y)
print max(Y[0:400])
plt.figure()
plt.xlim(0,40)
plt.ylim(0,60)
plt.xlabel('')
plt.ylabel('')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('170.png')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-6782fd88d35e> in <module>()
# ----> 1 datos=np.loadtxt('datos170.txt',delimiter='&')
#       2 X=datos[:,0]
#       3 X2=X+1
#       4 Y=datos[:,1]
#       5 x=X[0:400]
#
# /Users/juanvargas/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     736                 fh = iter(bz2.BZ2File(fname))
#     737             elif sys.version_info[0] == 2:
# --> 738                 fh = iter(open(fname, 'U'))
#     739             else:
#     740                 fh = iter(open(fname))
#
# IOError: [Errno 2] No such file or directory: 'datos170.txt'

# %%
datos=np.loadtxt('datos150.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,40)
plt.ylim(0,60)
plt.xlabel('')
plt.ylabel('')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('150.png')
# Out:
# 2.44

# %%
datos=np.loadtxt('datos120.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,40)
plt.ylim(0,60)
plt.xlabel('')
plt.ylabel('')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('120.png')

# %%
datos=np.loadtxt('datos1702.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,50)
plt.ylim(0,60)
plt.xlabel('')
plt.ylabel('')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('1702.png')

# %%
datos=np.loadtxt('datos1701-0.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,35)
plt.ylim(0,60)
plt.xlabel('')
plt.ylabel('')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('1701-0.png')
