# %%
import math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
datos=np.loadtxt('datos170.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
x=X[0:400]
print x[-1]
#print max(Y)
#print max(Y[0:400])
plt.figure()
plt.xlim(0,35)
plt.ylim(0,60)
plt.title('Temperatura 170$\degree$')
plt.xlabel('Voltaje $U_1(V)$')
plt.ylabel('Corriente $I(nA)$')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('170.png')
# Out:
# 9.76

# %%
datos=np.loadtxt('datos150.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,30)
plt.ylim(0,60)
plt.title('Temperatura 150$\degree$')
plt.xlabel('Voltaje $U_1(V)$')
plt.ylabel('Corriente $I(nA)$')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('150.png')

# %%
datos=np.loadtxt('datos120.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,30)
plt.ylim(0,60)
plt.title('Temperatura 120$\degree$')
plt.xlabel('Voltaje $U_1(V)$')
plt.ylabel('Corriente $I(nA)$')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('120.png')

# %%
datos=np.loadtxt('datos1702.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,45)
plt.ylim(0,60)
plt.title('Temperatura 170$\degree$ con $U_2=1$V')
plt.xlabel('Voltaje $U_1(V)$')
plt.ylabel('Corriente $I(nA)$')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('1702.png')

# %%
datos=np.loadtxt('datos1701-0.txt',delimiter='&')
X=datos[:,0]
X2=X+1
Y=datos[:,1]
plt.figure()
plt.xlim(0,35)
plt.ylim(0,60)
plt.title('Temperatura 170$\degree$ con $U_2=1.5$V ')
plt.xlabel('Voltaje $U_1(V)$')
plt.ylabel('Corriente $I(nA)$')
#plt.scatter(X,Y)
plt.plot(X,Y)
#plt.plot(X2,Y)
plt.savefig('1701-0.png')
